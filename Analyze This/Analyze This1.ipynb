# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import Imputer

from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-db9130ea523a> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2 import numpy as np
# ----> 3 import pandas as pd
#       4 import seaborn as sns
#       5 import matplotlib.pyplot as plt
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\__init__.py in <module>
#      53 import pandas.core.config_init
#      54
# ---> 55 from pandas.core.api import (
#      56     # dtype
#      57     Int8Dtype,
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\api.py in <module>
#       3 import numpy as np
#       4
# ----> 5 from pandas.core.arrays.integer import (
#       6     Int8Dtype,
#       7     Int16Dtype,
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\arrays\__init__.py in <module>
#       5     ExtensionScalarOpsMixin,
#       6 )
# ...

# %%
from sklearn.preprocessing import Imputer

train_df = pd.read_csv("development_dataset.csv",index_col=0)
leader_df = pd.read_csv("leaderboard_dataset.csv")
evaluation_df = pd.read_csv("Evaluation_dataset.csv")

# %%
train_df.head(10)
# Out:
#             VAR2      VAR3        VAR4        VAR5       VAR6      VAR7  \
# VAR1
# 1     828.235294  0.138889  321.428571  625.911006   1.818182  1.081550
# 2     911.764706  0.027778         NaN  611.574748   8.181818  1.344479
# 3     962.352941  0.833333   35.714286  615.825381   8.181818  0.720796
# 4     892.941177       NaN         NaN  638.076431   9.090909  0.820218
# 5     914.117647  0.083333         NaN  626.514988   5.181818  1.372928
# 6     794.117647  0.117700  178.571429  624.065797  12.727273  0.665458
# 7     987.058823       NaN   35.714286  611.574748        NaN  0.970320
# 8     921.176471  0.138889         NaN  612.660165  18.181818  0.585291
# 9     947.058823       NaN  821.428571  648.330121  23.636364  0.782048
# 10    940.000000  0.137778  107.142857  611.574748   9.090909  0.559710
#
#             VAR8        VAR9      VAR10     VAR11       VAR12      VAR13  \
# VAR1
# 1     198.113469         NaN  58.632548  0.279273  100.083403   1.000000
# ...

# %%
train_df.isnull().sum()/340
# Out:
# VAR2      2.826471
# VAR3      9.955882
# VAR4     36.747059
# VAR5      0.002941
# VAR6     10.279412
# VAR7      2.455882
# VAR8      2.455882
# VAR9     46.520588
# VAR10    13.382353
# VAR11    22.250000
# VAR12    30.888235
# VAR13    25.064706
# VAR14     0.000000
# VAR15    23.600000
# VAR16     2.547059
# VAR17    65.276471
# VAR18     0.000000
# VAR19     0.000000
# VAR20     0.000000
# VAR21     0.000000
# dtype: float64

# %%
train_df.dtypes
# Out:
# VAR2     float64
# VAR3     float64
# VAR4     float64
# VAR5     float64
# VAR6     float64
# VAR7     float64
# VAR8     float64
# VAR9     float64
# VAR10    float64
# VAR11    float64
# VAR12    float64
# VAR13    float64
# VAR14     object
# VAR15    float64
# VAR16    float64
# VAR17    float64
# VAR18      int64
# VAR19      int64
# VAR20    float64
# VAR21     object
# dtype: object

# %%
train_df = train_df.replace('.', 'nan')
train_df['VAR14'] = train_df['VAR14'].astype(float)

# %%
train_df.dtypes
# Out:
# VAR2     float64
# VAR3     float64
# VAR4     float64
# VAR5     float64
# VAR6     float64
# VAR7     float64
# VAR8     float64
# VAR9     float64
# VAR10    float64
# VAR11    float64
# VAR12    float64
# VAR13    float64
# VAR14    float64
# VAR15    float64
# VAR16    float64
# VAR17    float64
# VAR18      int64
# VAR19      int64
# VAR20    float64
# VAR21     object
# dtype: object

# %%
import sys
from impyute.imputation.cs import fast_knn
sys.setrecursionlimit(100000) #Increase the recursion limit of the OS
data = train_df.loc[:,:'VAR20']
# start the KNN training

# %%
data.columns
# Out:
# Index(['VAR2', 'VAR3', 'VAR4', 'VAR5', 'VAR6', 'VAR7', 'VAR8', 'VAR9', 'VAR10',
#        'VAR11', 'VAR12', 'VAR13', 'VAR14', 'VAR15', 'VAR16', 'VAR17', 'VAR18',
#        'VAR19', 'VAR20'],
#       dtype='object')

# %%
imputed_training=fast_knn(data.values, k=5)

# %%
imputed_training.shape
# Out:
# (34000, 19)

# %%
from numpy import loadtxt
from keras import optimizers
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import np_utils
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()    
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
imputed_training=pd.DataFrame(imputed_training)
imputed_training.loc[:, :'VAR20'] = scaler.fit_transform(imputed_training.loc[:, :'VAR20'])

# split into input (X) and output (y) variables
imputed_training = pd.DataFrame(imputed_training)
X = imputed_training.iloc[:,:]
y = train_df.iloc[:,19]
y2 = np_utils.to_categorical(lb.fit_transform(y))

from tpot import TPOTClassifier
from sklearn.model_selection import train_test_split


x_train, x_test, y_train, y_test = train_test_split(imputed_training, y2 ,
                                                    train_size=0.80, test_size=0.20)

pipeline_optimizer = TPOTClassifier(generations=5, population_size=20, cv=5,
                                    random_state=42, verbosity=2)
pipeline_optimizer.fit(x_train, y_train)
print(pipeline_optimizer.score(x_test, y_test))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-124-1db2bd77dbc0> in <module>
#      18 y2 = np_utils.to_categorical(lb.fit_transform(y))
#      19
# ---> 20 from tpot import TPOTClassifier
#      21 from sklearn.model_selection import train_test_split
#      22
#
# D:\Anaconda3\lib\site-packages\tpot\__init__.py in <module>
#      25
#      26 from ._version import __version__
# ---> 27 from .tpot import TPOTClassifier, TPOTRegressor
#      28 from .driver import main
#
# D:\Anaconda3\lib\site-packages\tpot\tpot.py in <module>
#      24 """
#      25
# ---> 26 from .base import TPOTBase
#      27 from .config.classifier import classifier_config_dict
#      28 from .config.regressor import regressor_config_dict
#
# D:\Anaconda3\lib\site-packages\tpot\base.py in <module>
#      49 from sklearn.base import BaseEstimator
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, Y2, test_size=0.2, random_state = 2)
# define the keras model
model = Sequential()
model.add(Dense(256, input_dim=19, activation='relu'))
model.add(Dense(128, activation='sigmoid'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='sigmoid'))
model.add(Dense(3, activation='softmax'))
# compile the keras model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit the keras model on the dataset
model.fit(x_train, y_train, epochs=15, batch_size=10)
# evaluate the keras model
ass1=model.predict(x_test)
_, accuracy = model.evaluate(x_test, y_test)
print('Accuracy: %.2f' % (accuracy*100))
